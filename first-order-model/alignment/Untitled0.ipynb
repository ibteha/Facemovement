# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/My Drive/Ayush Gupta/Image-animation/first-order-motion/first-order-model/alignment
# Out:
# /content/drive/My Drive/Ayush Gupta/Image-animation/first-order-motion/first-order-model/alignment

# %%
# !python face.py
# Out:
# <Figure size 640x480 with 1 Axes>
# rotate to inverse clock direction
# angle:  3.9909130984298775  in degree
# angle:  3.9909130984298775  in degree
# <Figure size 640x480 with 1 Axes>
# <Figure size 640x480 with 1 Axes>
